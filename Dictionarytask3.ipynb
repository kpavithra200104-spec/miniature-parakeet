# %%
students={
    "Arun":85,
    "Kavin":92,
    "Ravi":78,
    "Priya":95
    }
highest_marks=max(students.values())

for name,marks in students.items():
    if marks==highest_marks:
        print("Student with highest marks:",name)
        print("Marks:",marks)

# %%
employees={"E01":{"name":"Arun","salary":28000,"department":"HR"},
           "E02":{"name":"Kavin","salary":35000,"department":"IT"},
           "E03":{"name":"Ravi","salary":22000,"department":"Finance"},
           "E04":{"name":"Priya","salary":32000,"department":"Sales"}
           }
print("Employees earning above $30,000:")

for employee in employees.values():
    if employee["salary"]>30000:
        print(employee["name"],"-","$",employee["salary"],"-",employee["department"])

# %%
text="banana"
frequency={}
for char in text:
  frequency[char]=frequency.get(char,0)+1
  print(frequency)

# %%
sentence="python is easy and python is powerful"

words=sentence.split()
frequency={}

for word in words:
  frequency[word]=frequency.get(word,0)+1

  print("Word frequency:",frequency)

# %%
products={
    "Pen":10,"Book":50,"Bag":500,"Pencil":5}
product=input("Enter product name")
if product in products:
  print("Price:",products[product])
else:
  print("Product not found")

# %%
squares={}
for num in range(1,11):
  squares[num]=num**2
  print(squares)

# %%
dict1={"a":10,"b":20}
dict2={"c":30,"d":40}
merged_dict=dict1.copy()
merged_dict.update(dict2)
print("Merged dictionary:",merged_dict)

# %%
Student={"Arun":75,"Kavin":45,"Ravi":32,"Priya":88,"Suresh":25}

pass_students={}
fail_students={}

for name,marks in students.items():
    if marks>=40:
        pass_students[name]=marks
    else:
        fail_students[name]=marks

print("Passed students:",pass_students)
print("Failed students:",fail_students)

# %%
phone_book={}
while True:
  print("\n.Add")
  print("\2.Search")
  print("\3.Update")
  print("\4.Delete")
  print("\5.Exit")

choice=input("Enter your choice:")

if choice=="1":
        name=input("Enter name:")
        phone=input("Enter phone number:")
        phone_book[name]=phone
        print("Contact added.")

elif choice=="2":
       name=input("Enter name to search:")
       if  name in phone_book:
           print("Phone number:",phone_book[name])
       else:
           print("Contact not found.")

elif choice=="3":
        name=input("Enter name to update:")
        if name in phone_book:
            phone__book[name]=input("Enter new phone number:")
            print("Contact updated.")
        else:
            print("Contact not found.")

elif choice=="4":
        name=input("Enter name to delete:")
        if name in phone_book:
           del phone_book[name]
           print("Contact deleted.")
        else:
            print("Contact not found.")

elif choice=="5":
        print("Exiting program.")
        break
else:
        print("Invalid choice.Please try again")
# Out:
# Streaming output truncated to the last 5000 lines.
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# .Delete
# .Exit
#
# .Add
# .Search
# .Update
# ...

# %%
cart={"Apple":5,"Banana":2,"Milk":5}
total_quantit=sum(cart.values())
print("Shopping cart:",cart)
print("Total quantity:",total_quantity)
