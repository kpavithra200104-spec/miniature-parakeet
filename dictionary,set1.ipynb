# %%
a={1,2,3}
b={4,5,6}
a.update(b)
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={10,20,30,40}
a.discard(20)
print(a)
# Out:
# {40, 10, 30}

# %%
a={12,34,125}
a.remove(12)
print(a)
# Out:
# {34, 125}

# %%
student={"name":"pavi","age":18,"mark":90}
print(student)
# Out:
# {'name': 'pavi', 'age': 18, 'mark': 90}

# %%
student={"name":"Kavin"}
print(student)
# Out:
# {'name': 'Kavin'}

# %%
student={"place":"chennai"}
print(student)
# Out:
# {'place': 'chennai'}

# %%
dict={"Name":"Pavi","Age":"12","Domain":"Data analyst"}
print(dict)
print(dict["Name"])
print(dict["Age"])
print(dict["Domain"])
# Out:
# {'Name': 'Pavi', 'Age': '12', 'Domain': 'Data analyst'}
# Pavi
# 12
# Data analyst
